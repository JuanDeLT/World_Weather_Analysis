# %%
#import the dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key
import time
from datetime import datetime

# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
#3. create a set of 2000 random latitudes and longitudes
lats = np.random.uniform(-90.000,90.000,size=2000) #change to 2000 later
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

    #add the coordinates to a list
coordinates = list(lat_lngs)

# %%
#4. get the nearest city using the citipy module
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 773

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c6e6f21518d2b9e081824e96aa8b421c'

# %%
#create an empty list to hold the weather data 
city_data = []
# print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
  
#loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") #idk whats goin on here

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 16 | bad freienwalde
# Processing Record 2 of Set 16 | new norfolk
# Processing Record 3 of Set 16 | tasiilaq
# Processing Record 4 of Set 16 | busselton
# Processing Record 5 of Set 16 | salalah
# Processing Record 6 of Set 16 | cape town
# Processing Record 7 of Set 16 | rikitea
# Processing Record 8 of Set 16 | dana point
# Processing Record 9 of Set 16 | saint-georges
# Processing Record 10 of Set 16 | wembley
# Processing Record 11 of Set 16 | east london
# Processing Record 12 of Set 16 | zhigansk
# Processing Record 13 of Set 16 | correntina
# Processing Record 14 of Set 16 | ilo
# Processing Record 15 of Set 16 | puerto ayora
# Processing Record 16 of Set 16 | hermanus
# Processing Record 17 of Set 16 | yellowknife
# Processing Record 18 of Set 16 | hilo
# Processing Record 19 of Set 16 | rocha
# Processing Record 20 of Set 16 | avarua
# Processing Record 21 of Set 16 | acari
# Processing Record 22 of Set 16 | albany
# Processing Record 23 of Set 16 | cehegin
# Processing Record 24 of Set 16 | iguatemi
# Processing Record 25 of Set 16 | saskylakh
# Processing Record 26 of Set 16 | butaritari
# Processing Record 27 of Set 16 | hasaki
# Processing Record 28 of Set 16 | palafrugell
# Processing Record 29 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 16 | bodden town
# Processing Record 31 of Set 16 | arys
# Processing Record 32 of Set 16 | jamestown
# Processing Record 33 of Set 16 | lavrentiya
# Processing Record 34 of Set 16 | nikolskoye
# Processing Record 35 of Set 16 | hofn
# Processing Record 36 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 16 | prestea
# Processing Record 38 of Set 16 | vrises
# Processing Record 39 of Set 16 | qaanaaq
# Processing Record 40 of Set 16 | mataura
# Processing Record 41 of Set 16 | sulya
# Processing Record 42 of Set 16 | sao filipe
# Processing Record 43 of Set 16 | campbell river
# Processing Record 44 of Set 16 | ribeira grande
# Processing Record 45 of Set 16 | cidreira
# Processing Record 46 of Set 16 | bathsheba
# Processing Record 47 of Set 16 | mar del plata
# Processing Record 48 of Set 16 | quthing
# Processing Record 49 of Set 16 | necochea
# Processing Record 50 of Set 16 | kaitangata
# Processing Record 1 of Set 17 | bethel
# Processing Record 2 of Set 17 | hobart
# Processing Record 3 of Set 17 | saint-philippe
# Processing Record 4 of Set 17 | kirakira
# Processing Record 5 of Set 17 | comodoro rivadavia
# Processing Record 6 of Set 17 | dimitrovgrad
# Processing Record 7 of Set 17 | ocozocoautla
# City not found. Skipping...
# Processing Record 8 of Set 17 | moyale
# Processing Record 9 of Set 17 | the valley
# Processing Record 10 of Set 17 | bluff
# Processing Record 11 of Set 17 | port alfred
# Processing Record 12 of Set 17 | srednekolymsk
# Processing Record 13 of Set 17 | leningradskiy
# Processing Record 14 of Set 17 | isangel
# Processing Record 15 of Set 17 | kapaa
# Processing Record 16 of Set 17 | kodiak
# Processing Record 17 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 17 | staraya poltavka
# Processing Record 19 of Set 17 | saint george
# Processing Record 20 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 17 | hithadhoo
# Processing Record 22 of Set 17 | carnarvon
# Processing Record 23 of Set 17 | vanimo
# Processing Record 24 of Set 17 | mangrol
# Processing Record 25 of Set 17 | ushuaia
# Processing Record 26 of Set 17 | teknaf
# Processing Record 27 of Set 17 | mahebourg
# Processing Record 28 of Set 17 | prainha
# Processing Record 29 of Set 17 | vila velha
# Processing Record 30 of Set 17 | victoria
# Processing Record 31 of Set 17 | punta arenas
# Processing Record 32 of Set 17 | marzuq
# Processing Record 33 of Set 17 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 17 | thompson
# Processing Record 36 of Set 17 | nouakchott
# Processing Record 37 of Set 17 | dunedin
# Processing Record 38 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 17 | natal
# Processing Record 40 of Set 17 | muriwai beach
# Processing Record 41 of Set 17 | viedma
# Processing Record 42 of Set 17 | bubaque
# Processing Record 43 of Set 17 | dikson
# Processing Record 44 of Set 17 | tsienyane
# City not found. Skipping...
# Processing Record 45 of Set 17 | jamsa
# Processing Record 46 of Set 17 | arraial do cabo
# Processing Record 47 of Set 17 | barrow
# Processing Record 48 of Set 17 | sena madureira
# Processing Record 49 of Set 17 | kampot
# Processing Record 50 of Set 17 | inuvik
# Processing Record 1 of Set 18 | gobabis
# Processing Record 2 of Set 18 | chumikan
# Processing Record 3 of Set 18 | port pirie
# Processing Record 4 of Set 18 | haicheng
# Processing Record 5 of Set 18 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 18 | belaya gora
# Processing Record 8 of Set 18 | man
# Processing Record 9 of Set 18 | longyearbyen
# Processing Record 10 of Set 18 | pochutla
# Processing Record 11 of Set 18 | verkhnyaya inta
# Processing Record 12 of Set 18 | hamilton
# Processing Record 13 of Set 18 | road town
# Processing Record 14 of Set 18 | castro
# Processing Record 15 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 18 | coolum beach
# Processing Record 17 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 18 | grosseto
# Processing Record 19 of Set 18 | dong hoi
# Processing Record 20 of Set 18 | lebu
# Processing Record 21 of Set 18 | san quintin
# Processing Record 22 of Set 18 | padang
# Processing Record 23 of Set 18 | ostrovnoy
# Processing Record 24 of Set 18 | huambo
# Processing Record 25 of Set 18 | lagoa
# Processing Record 26 of Set 18 | tiksi
# Processing Record 27 of Set 18 | kununurra
# Processing Record 28 of Set 18 | aleksandrovsk-sakhalinskiy
# Processing Record 29 of Set 18 | mendi
# Processing Record 30 of Set 18 | port elizabeth
# Processing Record 31 of Set 18 | aklavik
# Processing Record 32 of Set 18 | dzaoudzi
# Processing Record 33 of Set 18 | coquimbo
# Processing Record 34 of Set 18 | harrisonville
# Processing Record 35 of Set 18 | codrington
# Processing Record 36 of Set 18 | pisco
# Processing Record 37 of Set 18 | mabaruma
# Processing Record 38 of Set 18 | baniachang
# Processing Record 39 of Set 18 | warangal
# Processing Record 40 of Set 18 | juan aldama
# Processing Record 41 of Set 18 | eyl
# Processing Record 42 of Set 18 | lincoln
# Processing Record 43 of Set 18 | marystown
# Processing Record 44 of Set 18 | atar
# Processing Record 45 of Set 18 | saint-leu
# Processing Record 46 of Set 18 | kurchum
# Processing Record 47 of Set 18 | meadow lake
# Processing Record 48 of Set 18 | natulongan
# City not found. Skipping...
# Processing Record 49 of Set 18 | smolenka
# Processing Record 50 of Set 18 | san patricio
# Processing Record 1 of Set 19 | campbellton
# Processing Record 2 of Set 19 | bredasdorp
# Processing Record 3 of Set 19 | ponta do sol
# Processing Record 4 of Set 19 | cayenne
# Processing Record 5 of Set 19 | kananga
# Processing Record 6 of Set 19 | talnakh
# Processing Record 7 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 19 | xiongshi
# City not found. Skipping...
# Processing Record 9 of Set 19 | atuona
# Processing Record 10 of Set 19 | chokurdakh
# Processing Record 11 of Set 19 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 19 | katsuura
# Processing Record 13 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 19 | khatanga
# Processing Record 15 of Set 19 | marienburg
# Processing Record 16 of Set 19 | bongandanga
# Processing Record 17 of Set 19 | krabi
# Processing Record 18 of Set 19 | vardo
# Processing Record 19 of Set 19 | mandalgovi
# Processing Record 20 of Set 19 | bengkulu
# Processing Record 21 of Set 19 | cabo san lucas
# Processing Record 22 of Set 19 | carmarthen
# Processing Record 23 of Set 19 | belmonte
# Processing Record 24 of Set 19 | tessalit
# Processing Record 25 of Set 19 | langsa
# Processing Record 26 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 19 | komsomolskiy
# Processing Record 28 of Set 19 | ewa beach
# Processing Record 29 of Set 19 | sitka
# Processing Record 30 of Set 19 | olinda
# Processing Record 31 of Set 19 | geraldton
# Processing Record 32 of Set 19 | la rioja
# Processing Record 33 of Set 19 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 19 | awbari
# Processing Record 35 of Set 19 | cao bang
# Processing Record 36 of Set 19 | idlib
# Processing Record 37 of Set 19 | broome
# Processing Record 38 of Set 19 | matagami
# Processing Record 39 of Set 19 | nanortalik
# Processing Record 40 of Set 19 | akdepe
# Processing Record 41 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 19 | torbay
# Processing Record 43 of Set 19 | labuan
# Processing Record 44 of Set 19 | ilhabela
# Processing Record 45 of Set 19 | coruripe
# Processing Record 46 of Set 19 | upernavik
# Processing Record 47 of Set 19 | saldanha
# Processing Record 48 of Set 19 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 19 | mut
# Processing Record 50 of Set 19 | koygorodok
# Processing Record 1 of Set 20 | tokonou
# Processing Record 2 of Set 20 | faanui
# Processing Record 3 of Set 20 | kavieng
# Processing Record 4 of Set 20 | hammerfest
# Processing Record 5 of Set 20 | ngunguru
# Processing Record 6 of Set 20 | pokhara
# Processing Record 7 of Set 20 | kahului
# Processing Record 8 of Set 20 | krasnovishersk
# Processing Record 9 of Set 20 | bonavista
# Processing Record 10 of Set 20 | kamiiso
# Processing Record 11 of Set 20 | zhigalovo
# Processing Record 12 of Set 20 | turangi
# Processing Record 13 of Set 20 | cukai
# Processing Record 14 of Set 20 | axim
# Processing Record 15 of Set 20 | marshfield
# Processing Record 16 of Set 20 | mizdah
# Processing Record 17 of Set 20 | abu dhabi
# Processing Record 18 of Set 20 | ayr
# Processing Record 19 of Set 20 | cairns
# Processing Record 20 of Set 20 | andenes
# Processing Record 21 of Set 20 | maragogi
# Processing Record 22 of Set 20 | unity
# Processing Record 23 of Set 20 | orlik
# Processing Record 24 of Set 20 | ostersund
# Processing Record 25 of Set 20 | lompoc
# Processing Record 26 of Set 20 | vaini
# Processing Record 27 of Set 20 | severo-kurilsk
# Processing Record 28 of Set 20 | egvekinot
# Processing Record 29 of Set 20 | mahon
# Processing Record 30 of Set 20 | ancud
# Processing Record 31 of Set 20 | jensen beach
# Processing Record 32 of Set 20 | odweyne
# Processing Record 33 of Set 20 | griffith
# Processing Record 34 of Set 20 | chapais
# Processing Record 35 of Set 20 | hundested
# Processing Record 36 of Set 20 | askiz
# Processing Record 37 of Set 20 | naze
# Processing Record 38 of Set 20 | opuwo
# Processing Record 39 of Set 20 | dinsor
# City not found. Skipping...
# Processing Record 40 of Set 20 | iwanai
# Processing Record 41 of Set 20 | teya
# Processing Record 42 of Set 20 | lukaya
# Processing Record 43 of Set 20 | la palma
# Processing Record 44 of Set 20 | matara
# Processing Record 45 of Set 20 | georgetown
# Processing Record 46 of Set 20 | banda aceh
# Processing Record 47 of Set 20 | thinadhoo
# Processing Record 48 of Set 20 | airai
# Processing Record 49 of Set 20 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 20 | ikungi
# Processing Record 1 of Set 21 | siderno
# Processing Record 2 of Set 21 | sobolevo
# Processing Record 3 of Set 21 | bamiantong
# Processing Record 4 of Set 21 | kannad
# Processing Record 5 of Set 21 | hurricane
# Processing Record 6 of Set 21 | alofi
# Processing Record 7 of Set 21 | zigong
# Processing Record 8 of Set 21 | bima
# Processing Record 9 of Set 21 | sao joao da barra
# Processing Record 10 of Set 21 | algarrobo
# Processing Record 11 of Set 21 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 21 | jibuti
# Processing Record 13 of Set 21 | skibotn
# Processing Record 14 of Set 21 | luderitz
# Processing Record 15 of Set 21 | chota
# Processing Record 16 of Set 21 | christchurch
# Processing Record 17 of Set 21 | sola
# Processing Record 18 of Set 21 | bethanien
# Processing Record 19 of Set 21 | kamenka
# Processing Record 20 of Set 21 | camacha
# Processing Record 21 of Set 21 | pokrovsk
# Processing Record 22 of Set 21 | naantali
# Processing Record 23 of Set 21 | abu samrah
# Processing Record 24 of Set 21 | sorland
# Processing Record 25 of Set 21 | savannah bight
# Processing Record 26 of Set 21 | sishui
# Processing Record 27 of Set 21 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 21 | touros
# Processing Record 29 of Set 21 | faya
# Processing Record 30 of Set 21 | kamina
# Processing Record 31 of Set 21 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 21 | coihaique
# Processing Record 34 of Set 21 | mecca
# Processing Record 35 of Set 21 | kalangala
# Processing Record 36 of Set 21 | stonewall
# Processing Record 37 of Set 21 | bar harbor
# Processing Record 38 of Set 21 | flinders
# Processing Record 39 of Set 21 | dwarka
# Processing Record 40 of Set 21 | san carlos de bariloche
# Processing Record 41 of Set 21 | aykhal
# Processing Record 42 of Set 21 | martapura
# Processing Record 43 of Set 21 | cap malheureux
# Processing Record 44 of Set 21 | chamba
# Processing Record 45 of Set 21 | souillac
# Processing Record 46 of Set 21 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 21 | barra patuca
# Processing Record 48 of Set 21 | beringovskiy
# Processing Record 49 of Set 21 | alugan
# Processing Record 50 of Set 21 | salinopolis
# Processing Record 1 of Set 22 | witrivier
# City not found. Skipping...
# Processing Record 2 of Set 22 | caravelas
# Processing Record 3 of Set 22 | alice springs
# Processing Record 4 of Set 22 | saint-francois
# Processing Record 5 of Set 22 | orangeburg
# Processing Record 6 of Set 22 | avera
# Processing Record 7 of Set 22 | los llanos de aridane
# Processing Record 8 of Set 22 | kytlym
# City not found. Skipping...
# Processing Record 9 of Set 22 | fortuna
# Processing Record 10 of Set 22 | plouzane
# Processing Record 11 of Set 22 | terrace
# Processing Record 12 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 22 | nome
# Processing Record 14 of Set 22 | ayan
# Processing Record 15 of Set 22 | klaksvik
# Processing Record 16 of Set 22 | lebowakgomo
# Processing Record 17 of Set 22 | clyde river
# Processing Record 18 of Set 22 | baie-comeau
# Processing Record 19 of Set 22 | mariinsk
# Processing Record 20 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 22 | port blair
# Processing Record 22 of Set 22 | sechura
# Processing Record 23 of Set 22 | itaituba
# Processing Record 24 of Set 22 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 22 | kushiro
# Processing Record 26 of Set 22 | funadhoo
# Processing Record 27 of Set 22 | adrar
# Processing Record 28 of Set 22 | kuryk
# Processing Record 29 of Set 22 | laguna
# Processing Record 30 of Set 22 | chuy
# Processing Record 31 of Set 22 | dingzhou
# Processing Record 32 of Set 22 | anadyr
# Processing Record 33 of Set 22 | sokoni
# Processing Record 34 of Set 22 | papasquiaro
# City not found. Skipping...
# Processing Record 35 of Set 22 | sinnamary
# Processing Record 36 of Set 22 | chabahar
# Processing Record 37 of Set 22 | hauterive
# Processing Record 38 of Set 22 | namatanai
# Processing Record 39 of Set 22 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 22 | omaruru
# Processing Record 41 of Set 22 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 22 | mareeba
# Processing Record 43 of Set 22 | boa vista
# Processing Record 44 of Set 22 | stornoway
# Processing Record 45 of Set 22 | kudahuvadhoo
# Processing Record 46 of Set 22 | tchibanga
# Processing Record 47 of Set 22 | oktyabrskoye
# Processing Record 48 of Set 22 | beloha
# Processing Record 49 of Set 22 | barahona
# Processing Record 50 of Set 22 | tomatlan
# Processing Record 1 of Set 23 | chhatak
# Processing Record 2 of Set 23 | tuktoyaktuk
# Processing Record 3 of Set 23 | emerald
# Processing Record 4 of Set 23 | codajas
# Processing Record 5 of Set 23 | bangui
# Processing Record 6 of Set 23 | lichinga
# Processing Record 7 of Set 23 | provideniya
# Processing Record 8 of Set 23 | kislyakovskaya
# Processing Record 9 of Set 23 | puerto carreno
# Processing Record 10 of Set 23 | ukiah
# Processing Record 11 of Set 23 | harper
# Processing Record 12 of Set 23 | agadez
# Processing Record 13 of Set 23 | amparai
# City not found. Skipping...
# Processing Record 14 of Set 23 | allapalli
# Processing Record 15 of Set 23 | nueva fuerza
# Processing Record 16 of Set 23 | garmsar
# Processing Record 17 of Set 23 | conde
# Processing Record 18 of Set 23 | dicabisagan
# Processing Record 19 of Set 23 | honiara
# Processing Record 20 of Set 23 | takanosu
# Processing Record 21 of Set 23 | curuca
# Processing Record 22 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 23 | gambo
# Processing Record 24 of Set 23 | portland
# Processing Record 25 of Set 23 | beira
# Processing Record 26 of Set 23 | paciran
# Processing Record 27 of Set 23 | ocos
# Processing Record 28 of Set 23 | maniitsoq
# Processing Record 29 of Set 23 | sur
# Processing Record 30 of Set 23 | lianran
# Processing Record 31 of Set 23 | caceres
# Processing Record 32 of Set 23 | petrivka
# Processing Record 33 of Set 23 | otradnoye
# Processing Record 34 of Set 23 | eldorado
# Processing Record 35 of Set 23 | taltal
# Processing Record 36 of Set 23 | alberdi
# Processing Record 37 of Set 23 | port-gentil
# Processing Record 38 of Set 23 | saint-augustin
# Processing Record 39 of Set 23 | linjiang
# Processing Record 40 of Set 23 | tagnanan
# Processing Record 41 of Set 23 | vostok
# Processing Record 42 of Set 23 | samarai
# Processing Record 43 of Set 23 | dubti
# Processing Record 44 of Set 23 | jumla
# Processing Record 45 of Set 23 | cururupu
# Processing Record 46 of Set 23 | muros
# Processing Record 47 of Set 23 | vancouver
# Processing Record 48 of Set 23 | dargaville
# Processing Record 49 of Set 23 | hovd
# Processing Record 50 of Set 23 | iqaluit
# Processing Record 1 of Set 24 | coahuayana
# Processing Record 2 of Set 24 | hervey bay
# Processing Record 3 of Set 24 | oriximina
# Processing Record 4 of Set 24 | naryan-mar
# Processing Record 5 of Set 24 | alto piquiri
# Processing Record 6 of Set 24 | guerrero negro
# Processing Record 7 of Set 24 | tromso
# Processing Record 8 of Set 24 | anloga
# Processing Record 9 of Set 24 | tsabong
# Processing Record 10 of Set 24 | erzin
# Processing Record 11 of Set 24 | lata
# Processing Record 12 of Set 24 | chara
# Processing Record 13 of Set 24 | lebedyn
# Processing Record 14 of Set 24 | ulladulla
# Processing Record 15 of Set 24 | rawson
# Processing Record 16 of Set 24 | shelburne
# Processing Record 17 of Set 24 | vestmannaeyjar
# Processing Record 18 of Set 24 | namibe
# Processing Record 19 of Set 24 | bilibino
# Processing Record 20 of Set 24 | bolshoy lug
# Processing Record 21 of Set 24 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 24 | las margaritas
# Processing Record 23 of Set 24 | yialos
# City not found. Skipping...
# Processing Record 24 of Set 24 | buncrana
# Processing Record 25 of Set 24 | ivanovka
# Processing Record 26 of Set 24 | saint-joseph
# Processing Record 27 of Set 24 | pevek
# Processing Record 28 of Set 24 | kroya
# Processing Record 29 of Set 24 | moshi
# Processing Record 30 of Set 24 | ritchie
# Processing Record 31 of Set 24 | norman wells
# Processing Record 32 of Set 24 | itarema
# Processing Record 33 of Set 24 | jambi
# Processing Record 34 of Set 24 | lusambo
# Processing Record 35 of Set 24 | yucca valley
# Processing Record 36 of Set 24 | penzance
# Processing Record 37 of Set 24 | rio grande
# Processing Record 38 of Set 24 | warrnambool
# Processing Record 39 of Set 24 | pembroke
# Processing Record 40 of Set 24 | muskogee
# Processing Record 41 of Set 24 | warmbad
# Processing Record 42 of Set 24 | tulsipur
# Processing Record 43 of Set 24 | neropolis
# Processing Record 44 of Set 24 | goya
# Processing Record 45 of Set 24 | bac lieu
# Processing Record 46 of Set 24 | waddan
# Processing Record 47 of Set 24 | sambava
# Processing Record 48 of Set 24 | dangriga
# Processing Record 49 of Set 24 | koungou
# Processing Record 50 of Set 24 | mahina
# Processing Record 1 of Set 25 | ihosy
# Processing Record 2 of Set 25 | lokosovo
# Processing Record 3 of Set 25 | faridan
# City not found. Skipping...
# Processing Record 4 of Set 25 | cherskiy
# Processing Record 5 of Set 25 | gat
# Processing Record 6 of Set 25 | isla mujeres
# Processing Record 7 of Set 25 | narsaq
# Processing Record 8 of Set 25 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 25 | la ronge
# Processing Record 10 of Set 25 | tuatapere
# Processing Record 11 of Set 25 | salinas
# Processing Record 12 of Set 25 | cortland
# Processing Record 13 of Set 25 | batagay-alyta
# Processing Record 14 of Set 25 | hegang
# Processing Record 15 of Set 25 | horodnytsya
# Processing Record 16 of Set 25 | bela
# Processing Record 17 of Set 25 | kenora
# Processing Record 18 of Set 25 | lorengau
# Processing Record 19 of Set 25 | manzanillo
# Processing Record 20 of Set 25 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 25 | poum
# Processing Record 22 of Set 25 | rundu
# Processing Record 23 of Set 25 | roma
# Processing Record 24 of Set 25 | guangyuan
# Processing Record 25 of Set 25 | bo rai
# Processing Record 26 of Set 25 | tayu
# Processing Record 27 of Set 25 | young
# Processing Record 28 of Set 25 | ilulissat
# Processing Record 29 of Set 25 | tual
# Processing Record 30 of Set 25 | mehamn
# Processing Record 31 of Set 25 | bababe
# City not found. Skipping...
# Processing Record 32 of Set 25 | japaratuba
# Processing Record 33 of Set 25 | fort-shevchenko
# Processing Record 34 of Set 25 | berlevag
# Processing Record 35 of Set 25 | calamar
# Processing Record 36 of Set 25 | sao jose da coroa grande
# Processing Record 37 of Set 25 | phrai bung
# City not found. Skipping...
# Processing Record 38 of Set 25 | kabinda
# Processing Record 39 of Set 25 | olafsvik
# Processing Record 40 of Set 25 | san luis rio colorado
# Processing Record 41 of Set 25 | okato
# Processing Record 42 of Set 25 | bud
# Processing Record 43 of Set 25 | kutum
# Processing Record 44 of Set 25 | karratha
# Processing Record 45 of Set 25 | fare
# Processing Record 46 of Set 25 | chokwe
# Processing Record 47 of Set 25 | santa vitoria do palmar
# Processing Record 48 of Set 25 | peabiru
# Processing Record 49 of Set 25 | esperance
# Processing Record 50 of Set 25 | clyde
# Processing Record 1 of Set 26 | margate
# Processing Record 2 of Set 26 | yulara
# Processing Record 3 of Set 26 | bandarbeyla
# Processing Record 4 of Set 26 | inverell
# Processing Record 5 of Set 26 | bograd
# Processing Record 6 of Set 26 | west bay
# Processing Record 7 of Set 26 | mabama
# Processing Record 8 of Set 26 | solhan
# Processing Record 9 of Set 26 | jaisalmer
# Processing Record 10 of Set 26 | porto murtinho
# Processing Record 11 of Set 26 | eminabad
# Processing Record 12 of Set 26 | sabzevar
# Processing Record 13 of Set 26 | tateyama
# Processing Record 14 of Set 26 | shatsk
# Processing Record 15 of Set 26 | kysyl-syr
# Processing Record 16 of Set 26 | champerico
# Processing Record 17 of Set 26 | jos
# Processing Record 18 of Set 26 | marsa matruh
# Processing Record 19 of Set 26 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 26 | sangar
# Processing Record 21 of Set 26 | filingue
# Processing Record 22 of Set 26 | beaverlodge
# Processing Record 23 of Set 26 | havre
# Processing Record 24 of Set 26 | esfarayen
# Processing Record 25 of Set 26 | shestakovo
# Processing Record 26 of Set 26 | botwood
# Processing Record 27 of Set 26 | bambous virieux
# Processing Record 28 of Set 26 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 26 | estelle
# Processing Record 30 of Set 26 | hirara
# Processing Record 31 of Set 26 | mount gambier
# Processing Record 32 of Set 26 | dudinka
# Processing Record 33 of Set 26 | morondava
# Processing Record 34 of Set 26 | saint-pierre
# Processing Record 35 of Set 26 | tautira
# Processing Record 36 of Set 26 | agbor
# Processing Record 37 of Set 26 | tambopata
# Processing Record 38 of Set 26 | yandoon
# City not found. Skipping...
# Processing Record 39 of Set 26 | hollister
# Processing Record 40 of Set 26 | weston
# Processing Record 41 of Set 26 | lynchburg
# Processing Record 42 of Set 26 | serebryansk
# Processing Record 43 of Set 26 | diamantino
# Processing Record 44 of Set 26 | morgan city
# Processing Record 45 of Set 26 | hearst
# Processing Record 46 of Set 26 | teguldet
# Processing Record 47 of Set 26 | ust-kuyga
# Processing Record 48 of Set 26 | sandnessjoen
# Processing Record 49 of Set 26 | san ciro de acosta
# Processing Record 50 of Set 26 | moratuwa
# Processing Record 1 of Set 27 | batabano
# Processing Record 2 of Set 27 | baykit
# Processing Record 3 of Set 27 | bambanglipuro
# Processing Record 4 of Set 27 | veraval
# Processing Record 5 of Set 27 | kavaratti
# Processing Record 6 of Set 27 | calama
# Processing Record 7 of Set 27 | ayagoz
# Processing Record 8 of Set 27 | pangai
# Processing Record 9 of Set 27 | tocopilla
# Processing Record 10 of Set 27 | watford
# Processing Record 11 of Set 27 | verkhoyansk
# Processing Record 12 of Set 27 | poso
# Processing Record 13 of Set 27 | linchuan
# City not found. Skipping...
# Processing Record 14 of Set 27 | salym
# Processing Record 15 of Set 27 | powell
# Processing Record 16 of Set 27 | evensk
# Processing Record 17 of Set 27 | dingle
# Processing Record 18 of Set 27 | whitianga
# Processing Record 19 of Set 27 | kasongo-lunda
# Processing Record 20 of Set 27 | chiang klang
# Processing Record 21 of Set 27 | taoudenni
# Processing Record 22 of Set 27 | lephepe
# City not found. Skipping...
# Processing Record 23 of Set 27 | cabedelo
# Processing Record 24 of Set 27 | aksarka
# Processing Record 25 of Set 27 | makakilo city
# Processing Record 26 of Set 27 | minot
# Processing Record 27 of Set 27 | pangody
# Processing Record 28 of Set 27 | tubuala
# Processing Record 29 of Set 27 | oranjemund
# Processing Record 30 of Set 27 | ahipara
# Processing Record 31 of Set 27 | husavik
# Processing Record 32 of Set 27 | fort nelson
# Processing Record 33 of Set 27 | tutoia
# Processing Record 34 of Set 27 | edea
# Processing Record 35 of Set 27 | koumac
# Processing Record 36 of Set 27 | marsabit
# Processing Record 37 of Set 27 | benghazi
# Processing Record 38 of Set 27 | sakakah
# Processing Record 39 of Set 27 | manzhouli
# Processing Record 40 of Set 27 | uruzgan
# Processing Record 41 of Set 27 | pacific grove
# Processing Record 42 of Set 27 | karpathos
# Processing Record 43 of Set 27 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 27 | maridi
# Processing Record 45 of Set 27 | elizabeth city
# Processing Record 46 of Set 27 | ambulu
# Processing Record 47 of Set 27 | pedernales
# Processing Record 48 of Set 27 | hokitika
# Processing Record 49 of Set 27 | carutapera
# Processing Record 50 of Set 27 | santa marinella
# Processing Record 1 of Set 28 | tuy hoa
# Processing Record 2 of Set 28 | lewistown
# Processing Record 3 of Set 28 | sioux lookout
# Processing Record 4 of Set 28 | khetri
# Processing Record 5 of Set 28 | roebourne
# Processing Record 6 of Set 28 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 28 | nhulunbuy
# Processing Record 8 of Set 28 | sharjah
# Processing Record 9 of Set 28 | porto novo
# Processing Record 10 of Set 28 | mitchell
# Processing Record 11 of Set 28 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 28 | hobyo
# Processing Record 13 of Set 28 | yurginskoye
# Processing Record 14 of Set 28 | kampong thum
# Processing Record 15 of Set 28 | san clemente
# Processing Record 16 of Set 28 | ossora
# Processing Record 17 of Set 28 | quang ngai
# Processing Record 18 of Set 28 | davila
# Processing Record 19 of Set 28 | fort madison
# Processing Record 20 of Set 28 | maliq
# Processing Record 21 of Set 28 | shibetsu
# Processing Record 22 of Set 28 | shihezi
# Processing Record 23 of Set 28 | bilma
# Processing Record 24 of Set 28 | joensuu
# Processing Record 25 of Set 28 | jacareacanga
# Processing Record 26 of Set 28 | tilichiki
# Processing Record 27 of Set 28 | terney
# Processing Record 28 of Set 28 | iracoubo
# Processing Record 29 of Set 28 | doembang nangbuat
# Processing Record 30 of Set 28 | alenquer
# Processing Record 31 of Set 28 | hays
# Processing Record 32 of Set 28 | dharmavaram
# Processing Record 33 of Set 28 | northam
# Processing Record 34 of Set 28 | nishihara
# Processing Record 35 of Set 28 | toulepleu
# City not found. Skipping...
# Processing Record 36 of Set 28 | tam ky
# Processing Record 37 of Set 28 | paamiut
# Processing Record 38 of Set 28 | velikodvorskiy
# Processing Record 39 of Set 28 | tukrah
# Processing Record 40 of Set 28 | trairi
# Processing Record 41 of Set 28 | mikkeli
# Processing Record 42 of Set 28 | boli
# Processing Record 43 of Set 28 | pozo colorado
# Processing Record 44 of Set 28 | santa isabel
# Processing Record 45 of Set 28 | bama
# Processing Record 46 of Set 28 | zhezkazgan
# Processing Record 47 of Set 28 | rabo de peixe
# Processing Record 48 of Set 28 | hunza
# City not found. Skipping...
# Processing Record 49 of Set 28 | tayoltita
# Processing Record 50 of Set 28 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 29 | mountain home
# Processing Record 2 of Set 29 | palmer
# Processing Record 3 of Set 29 | half moon bay
# Processing Record 4 of Set 29 | ixtapa
# Processing Record 5 of Set 29 | krutinka
# Processing Record 6 of Set 29 | sideropolis
# Processing Record 7 of Set 29 | amboasary
# Processing Record 8 of Set 29 | sisimiut
# Processing Record 9 of Set 29 | haines junction
# Processing Record 10 of Set 29 | zletovo
# Processing Record 11 of Set 29 | dalby
# Processing Record 12 of Set 29 | kurilsk
# Processing Record 13 of Set 29 | buritis
# Processing Record 14 of Set 29 | delta
# Processing Record 15 of Set 29 | minab
# Processing Record 16 of Set 29 | staryy nadym
# Processing Record 17 of Set 29 | poykovskiy
# Processing Record 18 of Set 29 | almaznyy
# Processing Record 19 of Set 29 | sanmenxia
# Processing Record 20 of Set 29 | makung
# City not found. Skipping...
# Processing Record 21 of Set 29 | birao
# Processing Record 22 of Set 29 | luoyang
# Processing Record 23 of Set 29 | scottsboro
# Processing Record 24 of Set 29 | cam ranh
# Processing Record 25 of Set 29 | safranbolu
# Processing Record 26 of Set 29 | miramar
# Processing Record 27 of Set 29 | kulachi
# Processing Record 28 of Set 29 | channel-port aux basques
# Processing Record 29 of Set 29 | maraa
# Processing Record 30 of Set 29 | broken hill
# Processing Record 31 of Set 29 | north bend
# Processing Record 32 of Set 29 | goderich
# Processing Record 33 of Set 29 | araguacu
# Processing Record 34 of Set 29 | bereznik
# Processing Record 35 of Set 29 | gebre guracha
# Processing Record 36 of Set 29 | moranbah
# Processing Record 37 of Set 29 | udaipur
# Processing Record 38 of Set 29 | yar-sale
# Processing Record 39 of Set 29 | shimoda
# Processing Record 40 of Set 29 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 29 | amahai
# Processing Record 42 of Set 29 | usinsk
# Processing Record 43 of Set 29 | port said
# Processing Record 44 of Set 29 | bani
# Processing Record 45 of Set 29 | riberalta
# Processing Record 46 of Set 29 | spornoye
# Processing Record 47 of Set 29 | quatre cocos
# Processing Record 48 of Set 29 | gimli
# Processing Record 49 of Set 29 | luwuk
# Processing Record 50 of Set 29 | fort saint james
# Processing Record 1 of Set 30 | urumqi
# Processing Record 2 of Set 30 | severnyy
# Processing Record 3 of Set 30 | vallenar
# Processing Record 4 of Set 30 | vangaindrano
# Processing Record 5 of Set 30 | dakar
# Processing Record 6 of Set 30 | kaeo
# Processing Record 7 of Set 30 | isiro
# Processing Record 8 of Set 30 | pointe-noire
# Processing Record 9 of Set 30 | bairiki
# Processing Record 10 of Set 30 | vanavara
# Processing Record 11 of Set 30 | mahanoro
# Processing Record 12 of Set 30 | port-de-paix
# City not found. Skipping...
# Processing Record 13 of Set 30 | kuching
# Processing Record 14 of Set 30 | pedro betancourt
# Processing Record 15 of Set 30 | spring hill
# Processing Record 16 of Set 30 | daru
# Processing Record 17 of Set 30 | konce
# Processing Record 18 of Set 30 | ganzhou
# Processing Record 19 of Set 30 | kazachinskoye
# Processing Record 20 of Set 30 | chulym
# Processing Record 21 of Set 30 | campos
# Processing Record 22 of Set 30 | basco
# Processing Record 23 of Set 30 | okhotsk
# Processing Record 24 of Set 30 | alamogordo
# Processing Record 25 of Set 30 | villarrica
# Processing Record 26 of Set 30 | bac can
# City not found. Skipping...
# Processing Record 27 of Set 30 | craig
# Processing Record 28 of Set 30 | chester
# Processing Record 29 of Set 30 | sivas
# Processing Record 30 of Set 30 | charlottesville
# Processing Record 31 of Set 30 | kanniyakumari
# Processing Record 32 of Set 30 | kargasok
# Processing Record 33 of Set 30 | sandusky
# Processing Record 34 of Set 30 | hohoe
# Processing Record 35 of Set 30 | ouesso
# Processing Record 36 of Set 30 | chaozhou
# Processing Record 37 of Set 30 | dahuk
# Processing Record 38 of Set 30 | temyasovo
# Processing Record 39 of Set 30 | rancho palos verdes
# Processing Record 40 of Set 30 | qandahar
# City not found. Skipping...
# Processing Record 41 of Set 30 | nandyal
# Processing Record 42 of Set 30 | whyalla
# Processing Record 43 of Set 30 | tsaratanana
# Processing Record 44 of Set 30 | vao
# Processing Record 45 of Set 30 | rincon
# Processing Record 46 of Set 30 | puerto palomas
# Processing Record 47 of Set 30 | lae
# Processing Record 48 of Set 30 | tallahassee
# Processing Record 49 of Set 30 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 30 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 31 | roald
# Processing Record 2 of Set 31 | rio cuarto
# Processing Record 3 of Set 31 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 31 | sayyan
# Processing Record 5 of Set 31 | cadolzburg
# Processing Record 6 of Set 31 | emilio carranza
# Processing Record 7 of Set 31 | seoul
# Processing Record 8 of Set 31 | pingliang
# Processing Record 9 of Set 31 | port hardy
# Processing Record 10 of Set 31 | cockburn town
# Processing Record 11 of Set 31 | smithers
# Processing Record 12 of Set 31 | pampa
# Processing Record 13 of Set 31 | henties bay
# Processing Record 14 of Set 31 | taihe
# Processing Record 15 of Set 31 | hinton
# Processing Record 16 of Set 31 | pangnirtung
# Processing Record 17 of Set 31 | ariquemes
# Processing Record 18 of Set 31 | burgos
# Processing Record 19 of Set 31 | byron bay
# Processing Record 20 of Set 31 | meulaboh
# Processing Record 21 of Set 31 | belogorsk
# Processing Record 22 of Set 31 | saint anthony
# Processing Record 23 of Set 31 | moerai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bad Freienwalde  52.7873   14.0304     53.76        75         100
# 1      New Norfolk -42.7826  147.0587     64.65        49         100
# 2         Tasiilaq  65.6145  -37.6368     23.16        58           5
# 3        Busselton -33.6500  115.3333     59.04        59          70
# 4          Salalah  17.0151   54.0924     71.69        60           0
#
#    Wind Speed Country                 Date Current Description
# 0       12.97      DE  2021-11-01 01:38:07     overcast clouds
# 1        4.00      AU  2021-11-01 01:38:07     overcast clouds
# 2        8.10      GL  2021-11-01 01:38:08           clear sky
# 3       20.33      AU  2021-11-01 01:33:54       broken clouds
# 4        3.44      OM  2021-11-01 01:38:08           clear sky

# %%
new_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0  Bad Freienwalde      DE  2021-11-01 01:38:07  52.7873   14.0304     53.76
# 1      New Norfolk      AU  2021-11-01 01:38:07 -42.7826  147.0587     64.65
# 2         Tasiilaq      GL  2021-11-01 01:38:08  65.6145  -37.6368     23.16
# 3        Busselton      AU  2021-11-01 01:33:54 -33.6500  115.3333     59.04
# 4          Salalah      OM  2021-11-01 01:38:08  17.0151   54.0924     71.69
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        75         100       12.97     overcast clouds
# 1        49         100        4.00     overcast clouds
# 2        58           5        8.10           clear sky
# 3        59          70       20.33       broken clouds
# 4        60           0        3.44           clear sky

# %%
#create the outptut file (CSV)
output_data_file = "WeatherPy_Database.csv"
#export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
